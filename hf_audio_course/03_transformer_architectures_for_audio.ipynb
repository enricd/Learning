# %% [markdown]
# ## 3. Transformer Architectures for Audio
#
# - 01 Refresher on Transformer models
# - 02 CTC architectures (Connectionist Temporal Classification)
# - 03 Seq2Seq architectures
# - 04 Audio classification architectures

# %% [markdown]
# ### 01 Refresher on Transformer models

# %% [markdown]
# ### 02 CTC (Connectionist Temporal Classification) architectures
#
# Encoder-only transformer models for automatic speech recognition (e.g. Wav2Vec2, HuBERT, M-CTC-T, etc.)

# %% [markdown]
# ### 03 Seq2Seq architectures

# %% [markdown]
# ### 04 Audio Classification Architectures
