# %%
# Scope -> Research -> Write -> Report

# %%
# Load environment variables and set up auto-reload
from dotenv import load_dotenv
load_dotenv()

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import show_prompt
from deep_research_from_scratch.prompts import clarify_with_user_instructions
show_prompt(clarify_with_user_instructions, "Clarify with User Instructions")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 from utils import show_prompt
# ----> 2 from ..deep_research_from_scratch.prompts import clarify_with_user_instructions
#       3 show_prompt(clarify_with_user_instructions, "Clarify with User Instructions")
#
# ImportError: attempted relative import with no known parent package
