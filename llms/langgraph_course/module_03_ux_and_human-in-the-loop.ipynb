# %% [markdown]
# ## Module 3: UX and Human-in-the-Loop
#
# - 01 Streaming
# - 02 Breakpoints
# - 03 Editing State and Human Feedback
# - 04 Dynamic Breakpoints
# - 05 Time Travel

# %% [markdown]
# ### 05 time travel
# graph.get_state()
